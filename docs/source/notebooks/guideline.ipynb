# %% [markdown]
# # Guideline on choosing receiver location spot
# ___

# %% [markdown]
# This notebook aims to provide you differents data for a location of the receiver, and show you the best height for placing it to perform GNSS reflectometry over a river or lac. Just enter your data and launch the notebook, you can directly see the result. You can then see what would be a good height for your receiver.
#
# If you want to test different height value than the default ones, just change the values in cell 5.
#
# Do not hesitate to export this notebook in pdf after running it.
#
# _For more information, documentation, example, see:_ https://github.com/lroineau/gnssr4river

# %% [markdown]
# ## User data
# ___
# Replace the data bellow by yours, following the example.

# %%
### Receiver coordinates ###
# Enter bellow the coordinates of your receiver (WGS84, i.e as given by Google Maps).
# If you know the ellipsoidal height of your receiver, even not precisely you can give it. Else set to 0.
lon = 7
lat = 52
h = 0

### Waterbody geometry ###
# If you have a .shp or a .gpck of your waterbody, enter the path bellow (as string), else set to None.
wb_path = None 

### Directory ###
# Would you like to save the files to be able to load them in QGIS? 
# Then choose the output format you want, gpkg, shp or kml
form='gpkg'
# Do you want to give a name to your location? This will be used in the plot
# If no, set to None
name=None

# %%
try:

    #general purpose libraires
    import math
    import numpy as np
    import pandas as pd
    import geopandas as gpd
    import fiona
    import cartopy
    import shapefile
    #visualization libraries
    # %matplotlib inline
    import matplotlib.pyplot as plt

    #project modules
    from gnssr4river.fresnel.fresnelzone import *
    from gnssr4river.fresnel.plotfresnel import *
    from gnssr4river.fresnel.iterfresnel import *
    from gnssr4river.fresnel.intersect import *
    print('All imports done succesfully')

except ImportError:
    raise ImportError('Fail to import one or more modules')
# Out:
# /usr/local/lib/python3.8/dist-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.8.0-CAPI-1.13.1). Conversions between both will be slow.
#   warnings.warn(
# All imports done succesfully

# %% [markdown]
# ## View of the spot
# ___

# %%
osm_image(lon,lat,50,sitename=name,style='satellite',save=False)

# %%
osm_image(lon,lat,50,sitename=name,style='map',save=False)

# %% [markdown]
# ## Height estimation
# ___

# %%
reflZone(0.5, [5,10,15],lon,lat)
reflZone(1, [5,10,15],lon,lat)
reflZone(1.5, [5,10,15],lon,lat)
reflZone(2, [5,10,15],lon,lat)
reflZone(2.5, [5,10,15],lon,lat)
reflZone(3, [5,10,15],lon,lat)
# Out:
# GPS week is: 2225
# File already exists
# _______________________________________________________________________________________
# Orbits for GPS and GLONASS satellites from 2022-09-01 06:00:00 to 2022-09-03 05:00:00
# _______________________________________________________________________________________
# File Fresnel[5, 10, 15]_0.5.gpkg successfully created in FresnelZones
# GPS week is: 2225
# File already exists
# _______________________________________________________________________________________
# Orbits for GPS and GLONASS satellites from 2022-09-01 06:00:00 to 2022-09-03 05:00:00
# _______________________________________________________________________________________
# File Fresnel[5, 10, 15]_1.gpkg successfully created in FresnelZones
# GPS week is: 2225
# File already exists
# _______________________________________________________________________________________
# Orbits for GPS and GLONASS satellites from 2022-09-01 06:00:00 to 2022-09-03 05:00:00
# ...

# %%
print('_______________')
print('Height of 0.5m')
print('_______________')

if wb_path==None:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_0.5.{form}')
else:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_0.5.{form}',filewb=wb_path)
# Out:
# _______________
# Height of 0.5m
# _______________
# No file for waterbody given

# %%
print('_______________')
print('Height of 1m')
print('_______________')

if wb_path==None:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_1.{form}')
else:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_1.{form}',filewb=wb_path)
# Out:
# _______________
# Height of 1m
# _______________
# No file for waterbody given

# %%
print('_______________')
print('Height of 1.5m')
print('_______________')

if wb_path==None:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_1.5.{form}')
else:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_1.5.{form}',filewb=wb_path)
# Out:
# _______________
# Height of 1.5m
# _______________
# No file for waterbody given

# %%
print('_______________')
print('Height of 2m')
print('_______________')

if wb_path==None:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_2.{form}')
else:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_2.{form}',filewb=wb_path)
# Out:
# _______________
# Height of 2m
# _______________
# No file for waterbody given

# %%
print('_______________')
print('Height of 2.5m')
print('_______________')

if wb_path==None:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_2.5.{form}')
else:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_2.5.{form}',filewb=wb_path)
# Out:
# _______________
# Height of 2.5m
# _______________
# No file for waterbody given

# %%
print('_______________')
print('Height of 3m')
print('_______________')

if wb_path==None:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_3.{form}')
else:
    fresnelMap(lon,lat,dist=20,sitename=name,filezone=f'FresnelZones/Fresnel[5, 10, 15]_3.{form}',filewb=wb_pathe=False)
# Out:
# _______________
# Height of 3m
# _______________
# No file for waterbody given
